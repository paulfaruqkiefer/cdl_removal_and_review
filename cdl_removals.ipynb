# %%
import requests
from bs4 import BeautifulSoup
import csv
import math
import os

BASE_URL = "https://tpr.fmcsa.dot.gov"
PAGE_URL = BASE_URL + "/Provider/InReview"
API_URL = BASE_URL + "/api/Public/InReviewPublic"

session = requests.Session()


def get_verification_token():
    """Fetch the HTML page and extract CSRF __RequestVerificationToken."""
    print("Fetching page to extract CSRF token...")
    r = session.get(PAGE_URL)
    r.raise_for_status()

    soup = BeautifulSoup(r.text, "html.parser")
    token_input = soup.find("input", {"name": "__RequestVerificationToken"})
    if not token_input:
        raise ValueError("Could not find __RequestVerificationToken in page HTML!")

    return token_input["value"]


def fetch_page(start, length, token):
    """Fetch one page of results using the DataTables API."""
    payload = {
        "draw": 1,
        "start": start,
        "length": length,
        "order[0][column]": 2,
        "order[0][orderable]": "true",
        "order[0][dir]": "desc",
        "columns[0][data]": "Name",
        "columns[1][data]": "City",
        "columns[2][data]": "PhysicalState",
        "search[regex]": "false",
        "__RequestVerificationToken": token,
    }

    headers = {
        "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
        "X-Requested-With": "XMLHttpRequest",
    }

    r = session.post(API_URL, data=payload, headers=headers)
    r.raise_for_status()
    return r.json()


def main():
    token = get_verification_token()

    print("Fetching first page to determine total rows...")
    first = fetch_page(start=0, length=10, token=token)
    total_records = first["recordsTotal"]
    print(f"Total records: {total_records}")

    page_size = 10
    total_pages = math.ceil(total_records / page_size)

    all_rows = first["data"]

    # Fetch remaining pages
    for page in range(1, total_pages):
        print(f"Fetching page {page+1}/{total_pages}...")
        start = page * page_size
        page_json = fetch_page(start=start, length=page_size, token=token)
        all_rows.extend(page_json["data"])

    print(f"Total rows downloaded: {len(all_rows)}")

    # ---- FIX: union of all keys across all rows ----
    all_keys = set()
    for row in all_rows:
        all_keys.update(row.keys())

    fieldnames = sorted(all_keys)

    # ---- Save CSV ----
    output_file = os.path.expanduser("~/Downloads/fmcsa_in_review.csv")

    with open(output_file, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames, extrasaction="ignore")
        writer.writeheader()
        writer.writerows(all_rows)

    print(f"\nSaved CSV to: {output_file}")


if __name__ == "__main__":
    main()
# Out:
# /Users/paulkiefer/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Fetching page to extract CSRF token...
# Fetching first page to determine total rows...
# Total records: 4530
# Fetching page 2/453...
# Fetching page 3/453...
# Fetching page 4/453...
# Fetching page 5/453...
# Fetching page 6/453...
# Fetching page 7/453...
# Fetching page 8/453...
# Fetching page 9/453...
# Fetching page 10/453...
# Fetching page 11/453...
# Fetching page 12/453...
# Fetching page 13/453...
# Fetching page 14/453...
# Fetching page 15/453...
# Fetching page 16/453...
# Fetching page 17/453...
# Fetching page 18/453...
# Fetching page 19/453...
# Fetching page 20/453...
# Fetching page 21/453...
# Fetching page 22/453...
# Fetching page 23/453...
# Fetching page 24/453...
# Fetching page 25/453...
# Fetching page 26/453...
# Fetching page 27/453...
# Fetching page 28/453...
# Fetching page 29/453...
# Fetching page 30/453...
# Fetching page 31/453...
# Fetching page 32/453...
# Fetching page 33/453...
# Fetching page 34/453...
# Fetching page 35/453...
# Fetching page 36/453...
# Fetching page 37/453...
# Fetching page 38/453...
# Fetching page 39/453...
# Fetching page 40/453...
# Fetching page 41/453...
# Fetching page 42/453...
# Fetching page 43/453...
# Fetching page 44/453...
# Fetching page 45/453...
# Fetching page 46/453...
# Fetching page 47/453...
# Fetching page 48/453...
# Fetching page 49/453...
# Fetching page 50/453...
# Fetching page 51/453...
# Fetching page 52/453...
# Fetching page 53/453...
# Fetching page 54/453...
# Fetching page 55/453...
# Fetching page 56/453...
# Fetching page 57/453...
# Fetching page 58/453...
# Fetching page 59/453...
# Fetching page 60/453...
# Fetching page 61/453...
# Fetching page 62/453...
# Fetching page 63/453...
# Fetching page 64/453...
# Fetching page 65/453...
# Fetching page 66/453...
# Fetching page 67/453...
# Fetching page 68/453...
# Fetching page 69/453...
# Fetching page 70/453...
# Fetching page 71/453...
# Fetching page 72/453...
# Fetching page 73/453...
# Fetching page 74/453...
# Fetching page 75/453...
# Fetching page 76/453...
# Fetching page 77/453...
# Fetching page 78/453...
# Fetching page 79/453...
# Fetching page 80/453...
# Fetching page 81/453...
# Fetching page 82/453...
# Fetching page 83/453...
# Fetching page 84/453...
# Fetching page 85/453...
# Fetching page 86/453...
# Fetching page 87/453...
# Fetching page 88/453...
# Fetching page 89/453...
# Fetching page 90/453...
# Fetching page 91/453...
# Fetching page 92/453...
# Fetching page 93/453...
# Fetching page 94/453...
# Fetching page 95/453...
# Fetching page 96/453...
# Fetching page 97/453...
# Fetching page 98/453...
# Fetching page 99/453...
# Fetching page 100/453...
# Fetching page 101/453...
# Fetching page 102/453...
# Fetching page 103/453...
# Fetching page 104/453...
# Fetching page 105/453...
# Fetching page 106/453...
# Fetching page 107/453...
# Fetching page 108/453...
# Fetching page 109/453...
# Fetching page 110/453...
# Fetching page 111/453...
# Fetching page 112/453...
# Fetching page 113/453...
# Fetching page 114/453...
# Fetching page 115/453...
# Fetching page 116/453...
# Fetching page 117/453...
# Fetching page 118/453...
# Fetching page 119/453...
# Fetching page 120/453...
# Fetching page 121/453...
# Fetching page 122/453...
# Fetching page 123/453...
# Fetching page 124/453...
# Fetching page 125/453...
# Fetching page 126/453...
# Fetching page 127/453...
# Fetching page 128/453...
# Fetching page 129/453...
# Fetching page 130/453...
# Fetching page 131/453...
# Fetching page 132/453...
# Fetching page 133/453...
# Fetching page 134/453...
# Fetching page 135/453...
# Fetching page 136/453...
# Fetching page 137/453...
# Fetching page 138/453...
# Fetching page 139/453...
# Fetching page 140/453...
# Fetching page 141/453...
# Fetching page 142/453...
# Fetching page 143/453...
# Fetching page 144/453...
# Fetching page 145/453...
# Fetching page 146/453...
# Fetching page 147/453...
# Fetching page 148/453...
# Fetching page 149/453...
# Fetching page 150/453...
# Fetching page 151/453...
# Fetching page 152/453...
# Fetching page 153/453...
# Fetching page 154/453...
# Fetching page 155/453...
# Fetching page 156/453...
# Fetching page 157/453...
# Fetching page 158/453...
# Fetching page 159/453...
# Fetching page 160/453...
# Fetching page 161/453...
# Fetching page 162/453...
# Fetching page 163/453...
# Fetching page 164/453...
# Fetching page 165/453...
# Fetching page 166/453...
# Fetching page 167/453...
# Fetching page 168/453...
# Fetching page 169/453...
# Fetching page 170/453...
# Fetching page 171/453...
# Fetching page 172/453...
# Fetching page 173/453...
# Fetching page 174/453...
# Fetching page 175/453...
# Fetching page 176/453...
# Fetching page 177/453...
# Fetching page 178/453...
# Fetching page 179/453...
# Fetching page 180/453...
# Fetching page 181/453...
# Fetching page 182/453...
# Fetching page 183/453...
# Fetching page 184/453...
# Fetching page 185/453...
# Fetching page 186/453...
# Fetching page 187/453...
# Fetching page 188/453...
# Fetching page 189/453...
# Fetching page 190/453...
# Fetching page 191/453...
# Fetching page 192/453...
# Fetching page 193/453...
# Fetching page 194/453...
# Fetching page 195/453...
# Fetching page 196/453...
# Fetching page 197/453...
# Fetching page 198/453...
# Fetching page 199/453...
# Fetching page 200/453...
# Fetching page 201/453...
# Fetching page 202/453...
# Fetching page 203/453...
# Fetching page 204/453...
# Fetching page 205/453...
# Fetching page 206/453...
# Fetching page 207/453...
# Fetching page 208/453...
# Fetching page 209/453...
# Fetching page 210/453...
# Fetching page 211/453...
# Fetching page 212/453...
# Fetching page 213/453...
# Fetching page 214/453...
# Fetching page 215/453...
# Fetching page 216/453...
# Fetching page 217/453...
# Fetching page 218/453...
# Fetching page 219/453...
# Fetching page 220/453...
# Fetching page 221/453...
# Fetching page 222/453...
# Fetching page 223/453...
# Fetching page 224/453...
# Fetching page 225/453...
# Fetching page 226/453...
# Fetching page 227/453...
# Fetching page 228/453...
# Fetching page 229/453...
# Fetching page 230/453...
# Fetching page 231/453...
# Fetching page 232/453...
# Fetching page 233/453...
# Fetching page 234/453...
# Fetching page 235/453...
# Fetching page 236/453...
# Fetching page 237/453...
# Fetching page 238/453...
# Fetching page 239/453...
# Fetching page 240/453...
# Fetching page 241/453...
# Fetching page 242/453...
# Fetching page 243/453...
# Fetching page 244/453...
# Fetching page 245/453...
# Fetching page 246/453...
# Fetching page 247/453...
# Fetching page 248/453...
# Fetching page 249/453...
# Fetching page 250/453...
# Fetching page 251/453...
# Fetching page 252/453...
# Fetching page 253/453...
# Fetching page 254/453...
# Fetching page 255/453...
# Fetching page 256/453...
# Fetching page 257/453...
# Fetching page 258/453...
# Fetching page 259/453...
# Fetching page 260/453...
# Fetching page 261/453...
# Fetching page 262/453...
# Fetching page 263/453...
# Fetching page 264/453...
# Fetching page 265/453...
# Fetching page 266/453...
# Fetching page 267/453...
# Fetching page 268/453...
# Fetching page 269/453...
# Fetching page 270/453...
# Fetching page 271/453...
# Fetching page 272/453...
# Fetching page 273/453...
# Fetching page 274/453...
# Fetching page 275/453...
# Fetching page 276/453...
# Fetching page 277/453...
# Fetching page 278/453...
# Fetching page 279/453...
# Fetching page 280/453...
# Fetching page 281/453...
# Fetching page 282/453...
# Fetching page 283/453...
# Fetching page 284/453...
# Fetching page 285/453...
# Fetching page 286/453...
# Fetching page 287/453...
# Fetching page 288/453...
# Fetching page 289/453...
# Fetching page 290/453...
# Fetching page 291/453...
# Fetching page 292/453...
# Fetching page 293/453...
# Fetching page 294/453...
# Fetching page 295/453...
# Fetching page 296/453...
# Fetching page 297/453...
# Fetching page 298/453...
# Fetching page 299/453...
# Fetching page 300/453...
# Fetching page 301/453...
# Fetching page 302/453...
# Fetching page 303/453...
# Fetching page 304/453...
# Fetching page 305/453...
# Fetching page 306/453...
# Fetching page 307/453...
# Fetching page 308/453...
# Fetching page 309/453...
# Fetching page 310/453...
# Fetching page 311/453...
# Fetching page 312/453...
# Fetching page 313/453...
# Fetching page 314/453...
# Fetching page 315/453...
# Fetching page 316/453...
# Fetching page 317/453...
# Fetching page 318/453...
# Fetching page 319/453...
# Fetching page 320/453...
# Fetching page 321/453...
# Fetching page 322/453...
# Fetching page 323/453...
# Fetching page 324/453...
# Fetching page 325/453...
# Fetching page 326/453...
# Fetching page 327/453...
# Fetching page 328/453...
# Fetching page 329/453...
# Fetching page 330/453...
# Fetching page 331/453...
# Fetching page 332/453...
# Fetching page 333/453...
# Fetching page 334/453...
# Fetching page 335/453...
# Fetching page 336/453...
# Fetching page 337/453...
# Fetching page 338/453...
# Fetching page 339/453...
# Fetching page 340/453...
# Fetching page 341/453...
# Fetching page 342/453...
# Fetching page 343/453...
# Fetching page 344/453...
# Fetching page 345/453...
# Fetching page 346/453...
# Fetching page 347/453...
# Fetching page 348/453...
# Fetching page 349/453...
# Fetching page 350/453...
# Fetching page 351/453...
# Fetching page 352/453...
# Fetching page 353/453...
# Fetching page 354/453...
# Fetching page 355/453...
# Fetching page 356/453...
# Fetching page 357/453...
# Fetching page 358/453...
# Fetching page 359/453...
# Fetching page 360/453...
# Fetching page 361/453...
# Fetching page 362/453...
# Fetching page 363/453...
# Fetching page 364/453...
# Fetching page 365/453...
# Fetching page 366/453...
# Fetching page 367/453...
# Fetching page 368/453...
# Fetching page 369/453...
# Fetching page 370/453...
# Fetching page 371/453...
# Fetching page 372/453...
# Fetching page 373/453...
# Fetching page 374/453...
# Fetching page 375/453...
# Fetching page 376/453...
# Fetching page 377/453...
# Fetching page 378/453...
# Fetching page 379/453...
# Fetching page 380/453...
# Fetching page 381/453...
# Fetching page 382/453...
# Fetching page 383/453...
# Fetching page 384/453...
# Fetching page 385/453...
# Fetching page 386/453...
# Fetching page 387/453...
# Fetching page 388/453...
# Fetching page 389/453...
# Fetching page 390/453...
# Fetching page 391/453...
# Fetching page 392/453...
# Fetching page 393/453...
# Fetching page 394/453...
# Fetching page 395/453...
# Fetching page 396/453...
# Fetching page 397/453...
# Fetching page 398/453...
# Fetching page 399/453...
# Fetching page 400/453...
# Fetching page 401/453...
# Fetching page 402/453...
# Fetching page 403/453...
# Fetching page 404/453...
# Fetching page 405/453...
# Fetching page 406/453...
# Fetching page 407/453...
# Fetching page 408/453...
# Fetching page 409/453...
# Fetching page 410/453...
# Fetching page 411/453...
# Fetching page 412/453...
# Fetching page 413/453...
# Fetching page 414/453...
# Fetching page 415/453...
# Fetching page 416/453...
# Fetching page 417/453...
# Fetching page 418/453...
# Fetching page 419/453...
# Fetching page 420/453...
# Fetching page 421/453...
# Fetching page 422/453...
# Fetching page 423/453...
# Fetching page 424/453...
# Fetching page 425/453...
# Fetching page 426/453...
# Fetching page 427/453...
# Fetching page 428/453...
# Fetching page 429/453...
# Fetching page 430/453...
# Fetching page 431/453...
# Fetching page 432/453...
# Fetching page 433/453...
# Fetching page 434/453...
# Fetching page 435/453...
# Fetching page 436/453...
# Fetching page 437/453...
# Fetching page 438/453...
# Fetching page 439/453...
# Fetching page 440/453...
# Fetching page 441/453...
# Fetching page 442/453...
# Fetching page 443/453...
# Fetching page 444/453...
# Fetching page 445/453...
# Fetching page 446/453...
# Fetching page 447/453...
# Fetching page 448/453...
# Fetching page 449/453...
# Fetching page 450/453...
# Fetching page 451/453...
# Fetching page 452/453...
# Fetching page 453/453...
# Total rows downloaded: 4530
#
# Saved CSV to: /Users/paulkiefer/Downloads/fmcsa_in_review.csv

# %%
import requests
from bs4 import BeautifulSoup
import csv
import math
import os

BASE_URL = "https://tpr.fmcsa.dot.gov"
PAGE_URL = BASE_URL + "/Provider/Removed"
API_URL = BASE_URL + "/api/Public/RemovedPublic"

session = requests.Session()


def get_verification_token():
    """Fetch the HTML page and extract CSRF __RequestVerificationToken."""
    print("Fetching page to extract CSRF token...")
    r = session.get(PAGE_URL)
    r.raise_for_status()

    soup = BeautifulSoup(r.text, "html.parser")
    token_input = soup.find("input", {"name": "__RequestVerificationToken"})
    if not token_input:
        raise ValueError("Could not find __RequestVerificationToken in page HTML!")

    return token_input["value"]


def fetch_page(start, length, token):
    """Fetch one page of results from FMCSA using DataTables parameters."""
    payload = {
        "draw": 1,
        "start": start,
        "length": length,

        # Sorting by PhysicalState descending (same as site)
        "order[0][column]": 2,
        "order[0][dir]": "desc",

        "columns[0][data]": "Name",
        "columns[0][searchable]": "true",
        "columns[0][orderable]": "true",

        "columns[1][data]": "City",
        "columns[1][searchable]": "true",
        "columns[1][orderable]": "true",

        "columns[2][data]": "PhysicalState",
        "columns[2][searchable]": "true",
        "columns[2][orderable]": "true",

        "search[regex]": "false",

        "__RequestVerificationToken": token,
    }

    headers = {
        "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
        "X-Requested-With": "XMLHttpRequest",
    }

    r = session.post(API_URL, data=payload, headers=headers)
    r.raise_for_status()
    return r.json()


def main():
    token = get_verification_token()

    print("Fetching first page to determine total rows...")
    first = fetch_page(start=0, length=10, token=token)
    total_records = first["recordsTotal"]
    print(f"Total records: {total_records}")

    page_size = 10
    total_pages = math.ceil(total_records / page_size)

    all_rows = first["data"]

    # Fetch the remaining pages
    for page in range(1, total_pages):
        print(f"Fetching page {page+1}/{total_pages}...")
        start = page * page_size
        page_json = fetch_page(start=start, length=page_size, token=token)
        all_rows.extend(page_json["data"])

    print(f"Downloaded {len(all_rows)} total rows.")

    # ---- Fix: union of all keys across all rows ----
    all_keys = set()
    for row in all_rows:
        all_keys.update(row.keys())

    fieldnames = sorted(all_keys)

    # ---- Save CSV ----
    output_file = os.path.expanduser("~/Downloads/fmcsa_removed_jan_6_2026.csv")

    with open(output_file, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames, extrasaction="ignore")
        writer.writeheader()
        writer.writerows(all_rows)

    print(f"\nSaved CSV to: {output_file}")


if __name__ == "__main__":
    main()
# Out:
# Fetching page to extract CSRF token...
# Fetching first page to determine total rows...
# Total records: 3080
# Fetching page 2/308...
# Fetching page 3/308...
# Fetching page 4/308...
# Fetching page 5/308...
# Fetching page 6/308...
# Fetching page 7/308...
# Fetching page 8/308...
# Fetching page 9/308...
# Fetching page 10/308...
# Fetching page 11/308...
# Fetching page 12/308...
# Fetching page 13/308...
# Fetching page 14/308...
# Fetching page 15/308...
# Fetching page 16/308...
# Fetching page 17/308...
# Fetching page 18/308...
# Fetching page 19/308...
# Fetching page 20/308...
# Fetching page 21/308...
# Fetching page 22/308...
# Fetching page 23/308...
# Fetching page 24/308...
# Fetching page 25/308...
# Fetching page 26/308...
# Fetching page 27/308...
# Fetching page 28/308...
# Fetching page 29/308...
# Fetching page 30/308...
# Fetching page 31/308...
# Fetching page 32/308...
# Fetching page 33/308...
# Fetching page 34/308...
# Fetching page 35/308...
# Fetching page 36/308...
# Fetching page 37/308...
# Fetching page 38/308...
# Fetching page 39/308...
# Fetching page 40/308...
# Fetching page 41/308...
# Fetching page 42/308...
# Fetching page 43/308...
# Fetching page 44/308...
# Fetching page 45/308...
# Fetching page 46/308...
# Fetching page 47/308...
# Fetching page 48/308...
# Fetching page 49/308...
# Fetching page 50/308...
# Fetching page 51/308...
# Fetching page 52/308...
# Fetching page 53/308...
# Fetching page 54/308...
# Fetching page 55/308...
# Fetching page 56/308...
# Fetching page 57/308...
# Fetching page 58/308...
# Fetching page 59/308...
# Fetching page 60/308...
# Fetching page 61/308...
# Fetching page 62/308...
# Fetching page 63/308...
# Fetching page 64/308...
# Fetching page 65/308...
# Fetching page 66/308...
# Fetching page 67/308...
# Fetching page 68/308...
# Fetching page 69/308...
# Fetching page 70/308...
# Fetching page 71/308...
# Fetching page 72/308...
# Fetching page 73/308...
# Fetching page 74/308...
# Fetching page 75/308...
# Fetching page 76/308...
# Fetching page 77/308...
# Fetching page 78/308...
# Fetching page 79/308...
# Fetching page 80/308...
# Fetching page 81/308...
# Fetching page 82/308...
# Fetching page 83/308...
# Fetching page 84/308...
# Fetching page 85/308...
# Fetching page 86/308...
# Fetching page 87/308...
# Fetching page 88/308...
# Fetching page 89/308...
# Fetching page 90/308...
# Fetching page 91/308...
# Fetching page 92/308...
# Fetching page 93/308...
# Fetching page 94/308...
# Fetching page 95/308...
# Fetching page 96/308...
# Fetching page 97/308...
# Fetching page 98/308...
# Fetching page 99/308...
# Fetching page 100/308...
# Fetching page 101/308...
# Fetching page 102/308...
# Fetching page 103/308...
# Fetching page 104/308...
# Fetching page 105/308...
# Fetching page 106/308...
# Fetching page 107/308...
# Fetching page 108/308...
# Fetching page 109/308...
# Fetching page 110/308...
# Fetching page 111/308...
# Fetching page 112/308...
# Fetching page 113/308...
# Fetching page 114/308...
# Fetching page 115/308...
# Fetching page 116/308...
# Fetching page 117/308...
# Fetching page 118/308...
# Fetching page 119/308...
# Fetching page 120/308...
# Fetching page 121/308...
# Fetching page 122/308...
# Fetching page 123/308...
# Fetching page 124/308...
# Fetching page 125/308...
# Fetching page 126/308...
# Fetching page 127/308...
# Fetching page 128/308...
# Fetching page 129/308...
# Fetching page 130/308...
# Fetching page 131/308...
# Fetching page 132/308...
# Fetching page 133/308...
# Fetching page 134/308...
# Fetching page 135/308...
# Fetching page 136/308...
# Fetching page 137/308...
# Fetching page 138/308...
# Fetching page 139/308...
# Fetching page 140/308...
# Fetching page 141/308...
# Fetching page 142/308...
# Fetching page 143/308...
# Fetching page 144/308...
# Fetching page 145/308...
# Fetching page 146/308...
# Fetching page 147/308...
# Fetching page 148/308...
# Fetching page 149/308...
# Fetching page 150/308...
# Fetching page 151/308...
# Fetching page 152/308...
# Fetching page 153/308...
# Fetching page 154/308...
# Fetching page 155/308...
# Fetching page 156/308...
# Fetching page 157/308...
# Fetching page 158/308...
# Fetching page 159/308...
# Fetching page 160/308...
# Fetching page 161/308...
# Fetching page 162/308...
# Fetching page 163/308...
# Fetching page 164/308...
# Fetching page 165/308...
# Fetching page 166/308...
# Fetching page 167/308...
# Fetching page 168/308...
# Fetching page 169/308...
# Fetching page 170/308...
# Fetching page 171/308...
# Fetching page 172/308...
# Fetching page 173/308...
# Fetching page 174/308...
# Fetching page 175/308...
# Fetching page 176/308...
# Fetching page 177/308...
# Fetching page 178/308...
# Fetching page 179/308...
# Fetching page 180/308...
# Fetching page 181/308...
# Fetching page 182/308...
# Fetching page 183/308...
# Fetching page 184/308...
# Fetching page 185/308...
# Fetching page 186/308...
# Fetching page 187/308...
# Fetching page 188/308...
# Fetching page 189/308...
# Fetching page 190/308...
# Fetching page 191/308...
# Fetching page 192/308...
# Fetching page 193/308...
# Fetching page 194/308...
# Fetching page 195/308...
# Fetching page 196/308...
# Fetching page 197/308...
# Fetching page 198/308...
# Fetching page 199/308...
# Fetching page 200/308...
# Fetching page 201/308...
# Fetching page 202/308...
# Fetching page 203/308...
# Fetching page 204/308...
# Fetching page 205/308...
# Fetching page 206/308...
# Fetching page 207/308...
# Fetching page 208/308...
# Fetching page 209/308...
# Fetching page 210/308...
# Fetching page 211/308...
# Fetching page 212/308...
# Fetching page 213/308...
# Fetching page 214/308...
# Fetching page 215/308...
# Fetching page 216/308...
# Fetching page 217/308...
# Fetching page 218/308...
# Fetching page 219/308...
# Fetching page 220/308...
# Fetching page 221/308...
# Fetching page 222/308...
# Fetching page 223/308...
# Fetching page 224/308...
# Fetching page 225/308...
# Fetching page 226/308...
# Fetching page 227/308...
# Fetching page 228/308...
# Fetching page 229/308...
# Fetching page 230/308...
# Fetching page 231/308...
# Fetching page 232/308...
# Fetching page 233/308...
# Fetching page 234/308...
# Fetching page 235/308...
# Fetching page 236/308...
# Fetching page 237/308...
# Fetching page 238/308...
# Fetching page 239/308...
# Fetching page 240/308...
# Fetching page 241/308...
# Fetching page 242/308...
# Fetching page 243/308...
# Fetching page 244/308...
# Fetching page 245/308...
# Fetching page 246/308...
# Fetching page 247/308...
# Fetching page 248/308...
# Fetching page 249/308...
# Fetching page 250/308...
# Fetching page 251/308...
# Fetching page 252/308...
# Fetching page 253/308...
# Fetching page 254/308...
# Fetching page 255/308...
# Fetching page 256/308...
# Fetching page 257/308...
# Fetching page 258/308...
# Fetching page 259/308...
# Fetching page 260/308...
# Fetching page 261/308...
# Fetching page 262/308...
# Fetching page 263/308...
# Fetching page 264/308...
# Fetching page 265/308...
# Fetching page 266/308...
# Fetching page 267/308...
# Fetching page 268/308...
# Fetching page 269/308...
# Fetching page 270/308...
# Fetching page 271/308...
# Fetching page 272/308...
# Fetching page 273/308...
# Fetching page 274/308...
# Fetching page 275/308...
# Fetching page 276/308...
# Fetching page 277/308...
# Fetching page 278/308...
# Fetching page 279/308...
# Fetching page 280/308...
# Fetching page 281/308...
# Fetching page 282/308...
# Fetching page 283/308...
# Fetching page 284/308...
# Fetching page 285/308...
# Fetching page 286/308...
# Fetching page 287/308...
# Fetching page 288/308...
# Fetching page 289/308...
# Fetching page 290/308...
# Fetching page 291/308...
# Fetching page 292/308...
# Fetching page 293/308...
# Fetching page 294/308...
# Fetching page 295/308...
# Fetching page 296/308...
# Fetching page 297/308...
# Fetching page 298/308...
# Fetching page 299/308...
# Fetching page 300/308...
# Fetching page 301/308...
# Fetching page 302/308...
# Fetching page 303/308...
# Fetching page 304/308...
# Fetching page 305/308...
# Fetching page 306/308...
# Fetching page 307/308...
# Fetching page 308/308...
# Downloaded 3080 total rows.
#
# Saved CSV to: /Users/paulkiefer/Downloads/fmcsa_removed_jan_6_2026.csv
